# %% [markdown]
# # LABORATORIO (HERRAMIENTAS)
# ## LICENCIATURA EN ANALÍTICA DE NEGOCIOS
# ### Universidad del Aconcagua - Facultad de Ciencias Económicas y Jurídicas
#
# ---
#
# <img src="https://www.uda.edu.ar/wp-content/uploads/2021/05/logo-uda.png" width="300" />
#
# ---
#
# ## 📚 INFORMACIÓN GENERAL
#
# | Campo | Información |
# |-------|-------------|
# | **Ciclo Lectivo** | 2026 |
# | **Curso** | Segundo Año |
# | **Régimen de Cursado** | Semestral (segundo semestre) |
# | **Carga Horaria Total** | 96 horas reloj |
# | **Carga Horaria Semanal** | 6 horas reloj |
# | **Modalidad** | 100% Virtual |
# | **Correlatividad para Cursar** | No tiene |
# | **Correlatividad para Rendir** | No tiene |
#
# ## 👨‍🏫 PROFESORES RESPONSABLES
#
# * **TITULAR**: ORTEGA YUBRO, Cristian Dario (cortega@uda.edu.ar)
# * **ADJUNTO**: MACHIN URBAY, Gustavo Raúl

# %% [markdown]
# ## 🎯 FUNDAMENTO DE LA ASIGNATURA
#
# ### ENCUADRE EN EL PLAN DE ESTUDIO
#
# La asignatura **Laboratorio** se encuentra ubicada en el segundo semestre de la carrera Licenciatura en Analítica de Negocios. Actúa como el **primer contacto inmersivo y fundacional** del estudiante con el ecosistema tecnológico analítico, proporcionando el soporte instrumental y metodológico necesario para el resto de las asignaturas del plan de estudios.
#
# Es una materia de carácter **eminentemente práctico y tecnológico**, diseñada para que los alumnos adquieran la capacidad de aplicar conocimientos teóricos mediante el uso de herramientas específicas de análisis, visualización y modelado operando directamente **en la nube**.
#
# Se distancia de los enfoques tradicionales centrados en software de escritorio local, introduciendo al estudiante en un **flujo de trabajo profesional, colaborativo y escalable**.
#
# ### EJES INSTRUMENTALES
#
# El desarrollo de la asignatura se articula en torno a tres ejes instrumentales:
#
# 1. **Entornos Cloud Colaborativos**: Adopción de plataformas de procesamiento mediante notebooks en la nube que eliminan las barreras de hardware local, permitiendo gestionar de manera eficiente la documentación del código y los recursos computacionales.
#
# 2. **Manipulación y Modelado Programático**: Introducción al procesamiento estructurado de datos y al modelado estadístico inicial mediante el uso de librerías de alto nivel (como Pandas y Scikit-learn).
#
# 3. **Visualización Directa y Dinámica**: Desarrollo de paneles de control y reportes interactivos orientados a la analítica de negocios, priorizando la eficiencia del código mediante la utilización exclusiva de la librería **Plotly Express**.
#
# ### RESULTADO ESPERADO
#
# Al finalizar el cursado, el estudiante habrá consolidado una **base operativa robusta**, siendo capaz de integrar la extracción, limpieza, análisis exploratorio y comunicación visual de los datos en un único ciclo de trabajo integral.
#
# Esta formación temprana facilita la resolución de problemas empresariales reales basados en datos y prepara al alumno para abordar con éxito los desafíos de complejidad creciente a lo largo de su formación profesional.

# %% [markdown]
# ## 🎯 OBJETIVOS GENERALES DE LA ASIGNATURA
#
# 1. Proporcionar la oportunidad de **aplicar conocimientos teóricos** adquiridos a través de ejercicios y proyectos prácticos utilizando herramientas relevantes.
#
# 2. **Capacitar a los estudiantes** en el uso de herramientas y software específicos para análisis de datos, visualización y modelado.
#
# 3. Facilitar la **resolución de problemas empresariales reales** mediante el uso de herramientas avanzadas, fomentando el pensamiento crítico y la capacidad de desarrollar soluciones efectivas y basadas en datos.

# %% [markdown]
# ## 📚 CONTENIDOS DEL CURSO
#
# ### CONTENIDOS MÍNIMOS
#
# * Herramientas en la nube de Análisis de Datos
# * Herramientas en la nube de Visualización de Datos
# * Herramientas en la nube de Modelado de Datos
# * Desarrollo de proyectos integradores
#
# ---
#
# ### 📌 UNIDAD 1: HERRAMIENTAS EN LA NUBE DE ANÁLISIS DE DATOS
#
# #### Fundamentación
# La analítica moderna exige entornos que permitan la reproducibilidad y el procesamiento de alto rendimiento. Se busca que el alumno gestione flujos de trabajo en entornos de computación interactiva basados en notebooks compartidos en la nube.
#
# #### Objetivos de Aprendizaje
# * Gestionar flujos de trabajo en entornos de computación interactiva en la nube
# * Extraer, limpiar y explorar conjuntos de datos utilizando sistemas de archivos distribuidos
# * Implementar estructuras de datos de baja latencia para el análisis
#
# #### Contenidos Detallados
# 1. **Entornos Operativos**: Configuración de espacios de trabajo en la nube (Databricks), aprovisionamiento de micro-clústeres y gestión colaborativa de notebooks
# 2. **Gestión de Almacenamiento**: Utilización de sistemas de archivos distribuidos para la carga, lectura y administración de datos
# 3. **Computación con NumPy**: Creación de arreglos y operaciones vectorizadas
# 4. **Motores de Datos**: Procesamiento, limpieza y transformación de estructuras de datos utilizando Python (Pandas)
#
# #### Estrategia Metodológica
# Clase expositiva con demostraciones en vivo (Live Coding). Desarrollo de actividades virtuales sincrónicas por Google Meet y asincrónicas en la plataforma Moodle.
#
# #### Bibliografía Recomendada
# * McKinney, W. (2022): Python for Data Analysis
#
# ---
#
# ### 📊 UNIDAD 2: HERRAMIENTAS EN LA NUBE DE VISUALIZACIÓN DE DATOS
#
# #### Fundamentación
# La curación de datos y la capacidad de comunicar insights mediante visualizaciones interactivas son fundamentales para que el decisor interactúe con la información.
#
# #### Objetivos de Aprendizaje
# * Diseñar activos visuales dinámicos para el monitoreo de negocios
# * Desarrollar paneles de control funcionales integrados en el entorno de desarrollo
#
# #### Contenidos Detallados
# 1. **Visualizaciones Nativas**: Generación de gráficos básicos y perfilado de datos integrados en la plataforma cloud
# 2. **Interactividad con Plotly**: Creación de gráficos interactivos y dinámicos utilizando de manera exclusiva la librería **Plotly Express**
# 3. **Visualización de Negocios**: Construcción de tableros y empaquetado de celdas de resultados para conformar informes ejecutivos
#
# #### Estrategia Metodológica
# Resolución de casos prácticos y talleres de diseño de visualización interactiva en entornos colaborativos.
#
# #### Bibliografía Recomendada
# * Documentación oficial de Plotly Express
#
# ---
#
# ### 🤖 UNIDAD 3: HERRAMIENTAS EN LA NUBE DE MODELADO DE DATOS
#
# #### Fundamentación
# La escala de los datos es una variable crítica. El alumno aprenderá a estructurar datos centralizados y a aplicar modelos predictivos aprovechando el cómputo distribuido en la nube.
#
# #### Objetivos de Aprendizaje
# * Realizar análisis agregados complejos en grandes volúmenes de datos
# * Diseñar e implementar modelos predictivos para anticipar escenarios de negocio
#
# #### Contenidos Detallados
# 1. **Estructuración de Datos**: Creación de tablas, vistas y gestión de esquemas lógicos
# 2. **Agregación de Datos**: Mecánica de agrupamiento, aplicación de funciones personalizadas y transformación de grupos
# 3. **Preparación y Modelado**: Ingeniería de características y entrenamiento de modelos estadísticos integrando Scikit-learn
#
# #### Estrategia Metodológica
# Desarrollo de laboratorios guiados en el entorno cloud para fomentar el análisis de escenarios predictivos.
#
# #### Bibliografía Recomendada
# * Documentación técnica de Scikit-learn
#
# ---
#
# ### 🛠️ UNIDAD 4: DESARROLLO DE PROYECTOS INTEGRADORES
#
# #### Fundamentación
# El análisis integral es la esencia de la estrategia. Se busca que el alumno ejecute el ciclo de vida completo del dato para resolver un problema de negocio real.
#
# #### Objetivos de Aprendizaje
# * Facilitar la resolución de problemas empresariales reales mediante el uso de herramientas avanzadas
# * Fomentar el pensamiento crítico y la capacidad de desarrollar soluciones efectivas y basadas en datos
#
# #### Contenidos Detallados
# 1. **Diseño del Proyecto**: Formulación del caso de estudio y planificación en el entorno cloud
# 2. **Pipeline de Datos**: Ejecución práctica de un flujo de ingesta, limpieza y guardado estructurado
# 3. **Análisis y Presentación**: Despliegue de los dashboards interactivos y defensa de la documentación técnica generada
#
# #### Estrategia Metodológica
# Análisis de un caso real integrando metodologías de limpieza, visualización y modelado.

# %% [markdown]
# ## 📝 PLAN DE TRABAJOS PRÁCTICOS
#
# | N° | Nombre del TP | Unidad | Objetivos, descripción y/o características |
# |---|---|---|---|
# | **1** | Configuración Cloud y Almacenamiento | 1 | Configurar el espacio de trabajo en la nube y gestionar la carga de un dataset tabular mediante el sistema de archivos distribuido |
# | **2** | Manipulación Programática y Exploración | 1 | Transformar estructuras de datos utilizando Pandas y explorar la información procesada integrando celdas SQL |
# | **3** | Perfilado de Datos | 2 | Utilizar herramientas de profiling integradas en el notebook para reconocer distribuciones iniciales del dataset |
# | **4** | Dashboards | 2 | Diseñar activos visuales interactivos programando y agruparlos en un panel consolidado |
# | **5** | Estructuración y Agregación | 3 | Guardar dataframes como tablas estructuradas y aplicar funciones de agregación sobre métricas comerciales clave |
# | **6** | Feature Engineering y Modelado | 3 | Estandarizar variables numéricas y entrenar un modelo predictivo |
# | **7** | Diseño y Pipeline Integrador | 4 | Formular el caso de estudio empresarial y ejecutar el flujo práctico de ingesta, limpieza y guardado estructurado |
# | **8** | Presentación del Proyecto Final | 4 | Resolver el problema analítico presentando un informe ejecutivo apoyado en el dashboard y la documentación técnica |
#
# ### Dataset de Trabajo: Panadería La Espiga Dorada
#
# Todos los trabajos prácticos utilizarán un **dataset unificado de ventas de panadería** que contiene:
# * Datos de ventas diarias
# * Productos (panes, facturas, tortas, bebidas)
# * Clientes y sus preferencias
# * Información de sucursales
# * Datos de stock y producción
# * Métricas de rentabilidad
#
# Este dataset permite desarrollar análisis realistas de un negocio de retail, aplicando todas las técnicas aprendidas en cada unidad.

# %% [markdown]
# ## 🏛️ METODOLOGÍA DE TRABAJO
#
# ### Modalidad: 100% Virtual
#
# La Facultad de Ciencias Económicas y Jurídicas, teniendo en cuenta normativas nacionales del sistema universitario y la experiencia adquirida en los últimos años, ha dispuesto para las clases de este ciclo lectivo, un modelo de cursado organizado con un **100% de virtualidad**.
#
# En el transcurso del semestre, la cátedra llevará adelante las siguientes actividades virtuales:
# * Clases sincrónicas por **Google Meet**
# * Videos subidos al aula virtual de la plataforma **Moodle**
# * Clases de consulta
# * Realización y evaluación de Trabajos Prácticos
# * Utilización del aula virtual de Moodle: material escrito de la disciplina, cuestionarios, foro, enlaces URL, etc.
#
# ### Metodología: "Aprender Haciendo" (Learning by Doing)
#
# La asignatura se describe como un **Laboratorio de herramientas** para el desarrollo de Analítica Avanzada. El dictado de clases no se limita a la exposición teórica, sino que se desarrolla mediante:
#
# * **Live Coding**: Resolución en tiempo real de problemas de negocio donde el docente modela el proceso de pensamiento y resolución de errores
# * **Entornos Colaborativos**: Uso intensivo de **Databricks Free Edition** y otras herramientas, permitiendo que la experimentación con datos ocurra en un entorno basado en la nube, eliminando barreras de hardware
#
# ---
#
# ## 📊 SISTEMA DE EVALUACIÓN
#
# ### Escala de Calificación
#
# Según la Res. 260/16 de CS, a partir del ciclo lectivo 2017, la nueva escala de calificaciones será ordinal, de calificación numérica, en la que el **mínimo exigible para aprobar** equivaldrá al **SESENTA POR CIENTO (60%)**. Este porcentaje mínimo se traducirá, en la escala numérica, a un **SEIS (6)**.
#
# | Escala porcentual % | Escala numérica Nota | Resultado |
# |---|---|---|
# | 0% | 0 | NO APROBADO |
# | 1 a 12% | 1 | NO APROBADO |
# | 13 a 24% | 2 | NO APROBADO |
# | 25 a 35% | 3 | NO APROBADO |
# | 36 a 47% | 4 | NO APROBADO |
# | 48 a 59% | 5 | NO APROBADO |
# | **60 a 64%** | **6** | **APROBADO** |
# | 65 a 74% | 7 | APROBADO |
# | 75 a 84% | 8 | APROBADO |
# | 85 a 94% | 9 | APROBADO |
# | 95 a 100% | 10 | APROBADO |
#
# ### Condiciones de Regularidad
#
# Las condiciones de regularidad se obtendrán de la siguiente manera:
#
# * **Alumno regular**: asistencia a por lo menos el **70%** de las clases y aprobación de **dos (2) exámenes parciales**
# * **Alumno no regular**: asistencia a por lo menos el **40%** de las clases y aprobación de **un (1) examen parcial**
# * **Alumno recursante**: aquel que no alcance los requisitos mencionados anteriormente

# %% [markdown]
# ## 📚 BIBLIOGRAFÍA
#
# ### Bibliografía Obligatoria
#
# * **McKinney, W. (2022)**. *Python for Data Analysis: Data Wrangling with pandas, NumPy, and Jupyter* (3rd ed.). O'Reilly Media.
#
# ### Bibliografía Complementaria
#
# * **Plotly Express Documentation**: Plotly Open Source Graphing Library for Python. [plotly.com/python/plotly-express/](https://plotly.com/python/plotly-express/)
# * **Pandas User Guide**: pandas: powerful Python data analysis toolkit. [pandas.pydata.org/docs/user_guide/](https://pandas.pydata.org/docs/user_guide/)
# * **Scikit-Learn Documentation**: scikit-learn: machine learning in Python. [scikit-learn.org/stable/documentation.html](https://scikit-learn.org/stable/documentation.html)
#
# ### Bibliografía en Línea
#
# * [www.uda.edu.ar/bibliotecadigital](http://www.uda.edu.ar/bibliotecadigital)
# * E-MAIL DE BIBLIOTECA: biblioteca@uda.edu.ar

# %% [markdown]
# ## 📁 ESTRUCTURA DEL REPOSITORIO
#
# ### Organización de Carpetas
#
# Este curso está organizado en un repositorio Git sincronizado con GitHub. Toda la estructura del curso se encuentra dentro de la carpeta:
#
# **`/Workspace/Users/cortega@uda.edu.ar/Laboratorio/`**
#
# ### 📋 Contenidos por Carpeta
#
# #### 📚 Programa del Curso
# Contiene este notebook con toda la información del programa de la asignatura.
#
# #### 🔹 Unidad 1: Análisis de Datos
# * **Teoria/**: Material teórico sobre entornos cloud, NumPy y Pandas
# * **Practicas/**:
#   * **TP01 - Configuración Cloud y Almacenamiento**: Configurar el entorno Databricks y gestionar archivos
#   * **TP02 - Manipulación Programática y Exploración**: Transformación de datos con Pandas y SQL
#
# #### 🔹 Unidad 2: Visualización de Datos
# * **Teoria/**: Material teórico sobre Plotly Express y visualizaciones
# * **Practicas/**:
#   * **TP03 - Perfilado de Datos**: Análisis exploratorio y profiling de datasets
#   * **TP04 - Dashboards Interactivos**: Creación de paneles interactivos con Plotly
#
# #### 🔹 Unidad 3: Modelado de Datos
# * **Teoria/**: Material teórico sobre agregación y Scikit-learn
# * **Practicas/**:
#   * **TP05 - Estructuración y Agregación**: Tablas estructuradas y agregaciones
#   * **TP06 - Feature Engineering y Modelado**: Ingeniería de características y modelado predictivo
#
# #### 🔹 Unidad 4: Proyectos Integradores
# * **TP07 - Pipeline Integrador**: Pipeline completo de análisis de datos
# * **TP08 - Proyecto Final**: Proyecto final integrador
#
# > **📌 Nota Importante**: Cada trabajo práctico está ubicado dentro de la carpeta `Practicas/` de su unidad correspondiente, facilitando la organización por temas y siguiendo la estructura pedagógica del curso. Los TPs se desarrollan progresivamente a medida que se avanza en cada unidad.
#
# #### 📂 Datasets
# Contiene todos los datasets utilizados en el curso, principalmente:
# * **ventas_panaderia.csv**: Dataset principal de ventas de panadería
# * **productos.csv**: Catálogo de productos
# * **clientes.csv**: Información de clientes
# * **sucursales.csv**: Datos de sucursales
#
# #### 📖 Bibliografía
# Material bibliográfico del curso en formato PDF
